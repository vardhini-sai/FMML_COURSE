# %% [markdown]
# <a href="https://colab.research.google.com/github/vardhini-sai/FMML_COURSE/blob/main/mod_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-03-31 11:45:41--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   203MB/s    in 0.3s
#
# 2024-03-31 11:45:42 (203 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 2603   1609.09869v2  Gaussian state space models have been used for...  stat
# 3330   1509.02805v3  Previously in 2014, we proposed the Nearest De...  stat
# 18011  cs/0010037v1  In fuzzy propositional logic, to a proposition...    cs
# 22805  1707.03003v2  Tick is a statistical learning library for Pyt...  stat
# 12094  1708.02635v2  Anomaly detection in database management syste...  stat
# ...             ...                                                ...   ...
# 18967   1301.3894v1  In this paper, we present a heuristic operator...    cs
# 34921   1207.6656v2  Ultra-large scale (ULS) systems are becoming p...    cs
# 12909   1010.1437v1  Transactional network data can be thought of a...  stat
# 3341   1511.06067v3  Large CNNs have delivered impressive performan...    cs
# 33661  1506.08867v1  The Java implementation of a portfolio of para...    cs
#
#                                                    title  year  \
# 2603   Structured Inference Networks for Nonlinear St...  2016
# 3330   Clustering by Hierarchical Nearest Neighbor De...  2015
# 18011  On the relationship between fuzzy logic and fo...  2000
# 22805  Tick: a Python library for statistical learnin...  2017
# 12094  Anomaly Detection in Multivariate Non-stationa...  2017
# ...                                                  ...   ...
# 18967  On the Use of Skeletons when Learning in Bayes...  2013
# 34921  Measuring the Complexity of Ultra-Large-Scale ...  2012
# 12909  Mixed-Membership Stochastic Block-Models for T...  2010
# 3341   Convolutional neural networks with low-rank re...  2015
# 33661  Java Implementation of a Parameter-less Evolut...  2015
#
#                                                 keywords
# 2603   [generative, sequential, intuitive, probabilis...
# 3330   [previously, generating, efficient, beautiful,...
# 18011  [propositional, proposition, circumstances, co...
# 22805  [statistical, particular, dependent, processes...
# 12094  [detection, management, difficult, increasing,...
# ...                                                  ...
# 18967  [heuristic, simultaneously, optimizing, orient...
# 34921  [pervasive, inherently, challenge, traditional...
# 12909  [transactional, relations, membership, transac...
# 3341   [delivered, impressive, performance, applicati...
# 33661  [implementation, portfolio, parameter, evoluti...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 2603     [generative, sequential, intuitive, probabilis...
# 3330     [previously, generating, efficient, beautiful,...
# 18011    [propositional, proposition, circumstances, co...
# 22805    [statistical, particular, dependent, processes...
# 12094    [detection, management, difficult, increasing,...
#                                ...
# 12700    [approximating, similarity, similarity, symmet...
# 38533    [fingerprints, characteristics, personnel, ide...
# 22095    [additional, submission, describes, algorithm,...
# 11225    [extremely, techniques, important, application...
# 13192    [perturbation, inequalities, perturbation, app...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8856 words.
# Out of those 4611 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="caeb7c72-59b7-446c-a5cc-335007cc26da" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("caeb7c72-59b7-446c-a5cc-335007cc26da")) {                    Plotly.newPlot(                        "caeb7c72-59b7-446c-a5cc-335007cc26da",                        [{"x":["leveraging","inference","structured","distributions","interpretation","scalability","simultaneously","probabilistic","parameterized","sequential","recurrent","introduce","approximation","including","distribution","significantly","likelihood","synthetic","versatility","variational","posterior","functional","nonlinear","efficiently","generative","intuitive","demonstrating","transition","widespread","algorithm","efficient","additional","subsequently","constraint","previously","requirement","occurring","effectively","neighborhood","overcomes","constructed","seemingly","generated","dimensions","attributes","generating","computation","structure","effective","construct","redundant","generates","automatically","hierarchical","specifically","segmented","identified","situation","partitioning","consequently","clustering","generally","contradiction","propositional","circumstances","proposition","propositions","consequence","entailment","conditions","considered","relevance","relationship","collapses","classical","computations","providing","regularization","processes","computational","generalized","particular","statistical","algorithms","documentation","modelling","dependent","optimization","implementation","downloaded","operators","investigated","determine","increasing","multivariate","effectiveness","especially","detection","automatic","statistics","stationary","experiment","normalization","anomalies","autoencoder","publishing","management","configuration","diagnosis","containing","similarity","difficult","reconstruction","essential","framework","discriminate","asymptotically","significant","different","theoretically","hypothesis","experiments","incomplete","classification","designing","interpretable","analyzing","discrepancy","divergence","selection","extremely","furthermore","statistically","applications","adversarial","estimator","successfully","dimensional","measuring","important","underlying","nonparametric","establish","collections","construction","constructing","population","allocation","dependency","simulation","documents","published","sophisticated","guarantees","wasserstein","adaptation","efficiency","frameworks","theoretical","advantages","unsupervised","minimizing","probability","generalization","transportation","combining","transport","blockmodel","measurements","consisting","observations","representation","membership","blockmodels","relationships","stochastic","approximate","assumptions","exchangeability","relational","interaction","regulatory","information","complexity","explosion","simplification","proximity","distributional","translation","polysemic","exponential","neighbors","combinatorial","selecting","candidates","determining","disambiguation","comparison","coherence","processing"],"y":[35,188,99,115,58,41,96,147,18,68,144,328,118,234,192,234,63,126,3,46,33,43,54,138,113,29,33,29,7,844,401,109,29,81,103,33,10,120,25,9,72,2,159,52,66,87,132,360,251,81,15,56,180,91,170,24,60,30,14,32,134,66,4,20,11,6,7,17,14,138,142,37,60,2,91,29,75,79,98,287,66,274,150,593,3,64,78,299,134,4,43,32,74,111,21,212,110,355,207,74,30,77,30,3,23,2,41,34,61,68,146,144,95,68,525,12,7,239,735,53,49,626,37,487,48,37,66,12,27,156,44,173,33,409,94,22,80,190,34,371,119,18,43,26,76,47,41,26,47,83,70,40,20,59,6,56,147,27,159,82,136,44,172,85,13,115,6,2,51,60,62,388,22,0,66,108,121,65,0,27,71,4,649,232,10,6,11,22,108,2,50,19,41,45,32,42,15,122,13,312],"type":"bar"},{"x":["leveraging","inferenc ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4611,), (4611, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8225

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Training</span> <span style=''>and</span> <span style=''>Testing</span> <span style=''>Object</span> <span style='background-color:rgba(0, 255, 0, 0.5882352941176472);'>Detectors</span> <span style=''>with</span> <span style=''>Virtual</span> <span style=''>Images</span> <br/><br/><span style=''>In</span> <span style=''>the</span> <span style=''>area</span> <span style=''>of</span> <span style=''>computer</span> <span style=''>vision</span> <span style=''>deep</span> <span style=''>learning</span> <span style=''>has</span> <span style=''>produced</span> <span style=''>a</span> <span style=''>variety</span> <span style=''>of</span> <span style=''>state</span> <span style=''>of</span> <span style=''>the</span> <span style=''>art</span> <span style=''>models</span> <span style=''>that</span> <span style=''>rely</span> <span style=''>on</span> <span style=''>massive</span> <span style=''>labeled</span> <span style=''>data</span> <span style=''>However</span> <span style='background-color:rgba(0, 255, 0, 0.4545454545454545);'>collecting</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>annotating</span> <span style=''>images</span> <span style=''>from</span> <span style=''>the</span> <span style=''>real</span> <span style=''>world</span> <span style=''>has</span> <span style=''>a</span> <span style=''>great</span> <span style=''>demand</span> <span style=''>for</span> <span style=''>labor</span> <span style=''>and</span> <span style=''>money</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>investments</span> <span style=''>and</span> <span style=''>is</span> <span style=''>usually</span> <span style=''>too</span> <span style=''>passive</span> <span style=''>to</span> <span style=''>build</span> <span style=''>datasets</span> <span style=''>with</span> <span style=''>specific</span> <span style='background-color:rgba(0, 255, 0, 0.5161290322580645);'>characteristics</span> <span style=''>such</span> <span style=''>as</span> <span style=''>small</span> <span style=''>area</span> <span style=''>of</span> <span style=''>objects</span> <span style=''>and</span> <span style=''>high</span> <span style='background-color:rgba(0, 255, 0, 0.92);'>occlusion</span> <span style=''>level</span> <span style=''>Under</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>framework</span> <span style=''>of</span> <span style=''>Parallel</span> <span style=''>Vision</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>presents</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.33333333333333337);'>purposeful</span> <span style=''>way</span> <span style=''>to</span> <span style=''>design</span> <span style='background-color:rgba(0, 255, 0, 0.5260115606936417);'>artificial</span> <span style=''>scenes</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.37931034482758624);'>automatically</span> <span style=''>generate</span> <span style=''>virtual</span> <span style=''>images</span> <span style=''>with</span> <span style=''>precise</span> <span style='background-color:rgba(0, 255, 0, 0.8333333333333333);'>annotations</span> <span style=''>A</span> <span style=''>virtual</span> <span style=''>dataset</span> <span style=''>named</span> <span style=''>ParallelEye</span> <span style=''>is</span> <span style=''>built</span> <span style=''>which</span> <span style=''>can</span> <span style=''>be</span> <span style=''>used</span> <span style=''>for</span> <span style=''>several</span> <span style=''>computer</span> <span style=''>vision</span> <span style=''>tasks</span> <span style=''>Then</span> <span style=''>by</span> <span style=''>training</span> <span style=''>the</span> <span style=''>DPM</span> <span style=''>(Deformable</span> <span style=''>Parts</span> <span style=''>Model)</span> <span style=''>and</span> <span style=''>Faster</span> <span style=''>R</span> <span style=''>CNN</ ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Predicting</span> <span style=''>Surgery</span> <span style=''>Duration</span> <span style=''>with</span> <span style=''>Neural</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Heteroscedastic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Regression</span> <br/><br/><span style='background-color:rgba(255, 0, 0, 0.3);'>Scheduling</span> <span style=''>surgeries</span> <span style=''>is</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>challenging</span> <span style=''>task</span> <span style=''>due</span> <span style=''>to</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>fundamental</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>uncertainty</span> <span style=''>of</span> <span style=''>the</span> <span style=''>clinical</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>environment</span> <span style=''>as</span> <span style=''>well</span> <span style=''>as</span> <span style=''>the</span> <span style=''>risks</span> <span style=''>and</span> <span style=''>costs</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>associated</span> <span style=''>with</span> <span style=''>under</span> <span style=''>and</span> <span style=''>over</span> <span style=''>booking</span> <span style=''>We</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>investigate</span> <span style=''>neural</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>regression</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithms</span> <span style=''>to</span> <span style=''>estimate</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>parameters</span> <span style=''>of</span> <span style=''>surgery</span> <span style=''>case</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>durations</span> <span style=''>focusing</span> <span style=''>on</span> <span style=''>the</span> <span style=''>issue</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>heteroscedasticity</span> <span style=''>We</span> <span style=''>seek</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>simultaneously</span> <span style=''>estimate</span> <span style=''>the</span> <span style=''>duration</span> <span style=''>of</span> <span style=''>each</span> <span style=''>surgery</span> <span style=''>as</span> <span style=''>well</span> <span style=''>as</span> <span style=''>a</span> <span style=''>surgery</span> <span style=''>specific</span> <span style=''>notion</span> <span style=''>of</span> <span style=''>our</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>uncertainty</span> <span style=''>about</span> <span style=''>its</span> <span style=''>duration</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Estimating</span> <span style=''>this</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>uncertainty</span> <span style=''>can</span> <span style=''>lead</span> <span style=''>to</span> <span style=''>more</span> <span style=''>nuanced</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>effective</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>scheduling</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>strategies</span> <span style=''>as</span> <span style=''>we</span> <span style=''>are</span> <span style=''>able</span> <span style=''>to</span> <span style=''>schedule</span> <span style=''>surgeries</span> <span style=''>more</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>efficiently</span> <span style=''>while</span> <span style=''>allowing</span> <span style=''>an</span> <span style=''>informed</span> <span style=''>and</span> <span style=''>case</span> <span style=''>specific</span> <span style=''>margin</span> <span style=''>of</span> <span style=''>error</span> <span style=' ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.3697478991596639);'>Statistical</span> <span style=''>region</span> <span style=''>based</span> <span style=''>active</span> <span style=''>contours</span> <span style=''>with</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>exponential</span> <span style=''>family</span> <span style='background-color:rgba(255, 0, 0, 0.4066985645933015);'>observations</span> <br/><br/><span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>focus</span> <span style=''>on</span> <span style='background-color:rgba(255, 0, 0, 0.3697478991596639);'>statistical</span> <span style=''>region</span> <span style=''>based</span> <span style=''>active</span> <span style=''>contour</span> <span style=''>models</span> <span style=''>where</span> <span style=''>image</span> <span style=''>features</span> <span style=''>(eg</span> <span style=''>intensity)</span> <span style=''>are</span> <span style=''>random</span> <span style='background-color:rgba(255, 0, 0, 0.3881748071979435);'>variables</span> <span style=''>whose</span> <span style='background-color:rgba(255, 0, 0, 0.31059245960502696);'>distribution</span> <span style=''>belongs</span> <span style=''>to</span> <span style=''>some</span> <span style='background-color:rgba(255, 0, 0, 0.5671641791044775);'>parametric</span> <span style=''>family</span> <span style=''>(eg</span> <span style=''>exponential)</span> <span style=''>rather</span> <span style=''>than</span> <span style=''>confining</span> <span style='background-color:rgba(0, 255, 0, 0.4285714285714286);'>ourselves</span> <span style=''>to</span> <span style=''>the</span> <span style=''>special</span> <span style=''>Gaussian</span> <span style=''>case</span> <span style=''>Using</span> <span style=''>shape</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>derivation</span> <span style=''>tools</span> <span style=''>our</span> <span style=''>effort</span> <span style=''>focuses</span> <span style=''>on</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>constructing</span> <span style=''>a</span> <span style=''>general</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>expression</span> <span style=''>for</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>derivative</span> <span style=''>of</span> <span style=''>the</span> <span style=''>energy</span> <span style=''>(with</span> <span style=''>respect</span> <span style=''>to</span> <span style=''>a</span> <span style=''>domain)</span> <span style=''>and</span> <span style=''>derive</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>corresponding</span> <span style='background-color:rgba(0, 255, 0, 0.47126436781609193);'>evolution</span> <span style=''>speed</span> <span style=''>A</span> <span style=''>general</span> <span style=''>result</span> <span style=''>is</span> <span style=''>stated</span> <span style=''>within</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>framework</span> <span style=''>of</span> <span style=''>multi</span> <span style='background-color:rgba(255, 0, 0, 0.34355828220858897);'>parameter</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>exponential</span> <span style=''>family</span> <span style=''>More</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>particularly</span> <span style=''>when</span> <span style=''>using</span> <span style=''>Maximum</span> <span style='background-color:rgba(255, 0, 0, 0.520912547528517);'>Likelihood</span> <span style='background-color:rgba(255, 0, 0, 0.6989247311827956);'>estimators</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.47126436781609193);'>evolution</span> <span style=''>speed</span> <span style=''>has</span> <span style=''>a</span> <span style=''>closed</span> <span style=''>form</span> <span style='background-color:r ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Simple</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>connectome</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>inference</span> <span style=''>from</span> <span style=''>partial</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>correlation</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>statistics</span> <span style=''>in</span> <span style=''>calcium</span> <span style=''>imaging</span> <br/><br/><span style=''>In</span> <span style=''>this</span> <span style=''>work</span> <span style=''>we</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>simple</span> <span style=''>yet</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>effective</span> <span style=''>solution</span> <span style=''>to</span> <span style=''>the</span> <span style=''>problem</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>connectome</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>inference</span> <span style=''>in</span> <span style=''>calcium</span> <span style=''>imaging</span> <span style=''>data</span> <span style=''>The</span> <span style=''>proposed</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>consists</span> <span style=''>of</span> <span style=''>two</span> <span style=''>steps</span> <span style=''>First</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>processing</span> <span style=''>the</span> <span style=''>raw</span> <span style=''>signals</span> <span style=''>to</span> <span style=''>detect</span> <span style=''>neural</span> <span style=''>peak</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>activities</span> <span style=''>Second</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>inferring</span> <span style=''>the</span> <span style=''>degree</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>association</span> <span style=''>between</span> <span style=''>neurons</span> <span style=''>from</span> <span style=''>partial</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>correlation</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>statistics</span> <span style=''>This</span> <span style=''>paper</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>summarises</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>methodology</span> <span style=''>that</span> <span style=''>led</span> <span style=''>us</span> <span style=''>to</span> <span style=''>win</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Connectomics</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Challenge</span> <span style=''>proposes</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>simplified</span> <span style=''>version</span> <span style=''>of</span> <span style=''>our</span> <span style=''>method</span> <span style=''>and</span> <span style=''>finally</span> <span style=''>compares</span> <span style=''>our</span> <span style=''>results</span> <span style=''>with</span> <span style=''>respect</span> <span style=''>to</span> <span style=''>other</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>inference</span> <span style=''>methods</span> <br/><br/>

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	knowledge (0.12111468381564845)
# 	architecture (0.08503036798856735)
# 	segmentation (0.07431225437656305)
# 	experimental (0.1411218292247231)
# 	processing (0.11146838156484459)
# 	representation (0.13862093604858877)
# 	different (0.26259378349410506)
# 	detection (0.12683101107538405)
# 	convolutional (0.13147552697391926)
# 	recognition (0.14540907466952482)
#
# Some Statistics words are:
# 	convergence (0.12343828085957022)
# 	stochastic (0.12893553223388307)
# 	variables (0.13493253373313344)
# 	theoretical (0.14942528735632185)
# 	statistical (0.1629185407296352)
# 	distribution (0.18240879560219891)
# 	estimation (0.18940529735132433)
# 	dimensional (0.19440279860069964)
# 	inference (0.21039480259870064)
# 	regression (0.18490754622688654)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="b7cc2d26-bc18-4121-b0c5-6113314ab4d7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b7cc2d26-bc18-4121-b0c5-6113314ab4d7")) {                    Plotly.newPlot(                        "b7cc2d26-bc18-4121-b0c5-6113314ab4d7",                        [{"x":["leveraging","inference","structured","distributions","interpretation","scalability","simultaneously","probabilistic","parameterized","sequential","recurrent","introduce","approximation","including","distribution","significantly","likelihood","synthetic","versatility","variational","posterior","functional","nonlinear","efficiently","generative","intuitive","demonstrating","transition","widespread","algorithm","efficient","additional","subsequently","constraint","previously","requirement","occurring","effectively","neighborhood","overcomes","constructed","seemingly","generated","dimensions","attributes","generating","computation","structure","effective","construct","redundant","generates","automatically","hierarchical","specifically","segmented","identified","situation","partitioning","consequently","clustering","generally","contradiction","propositional","circumstances","proposition","propositions","consequence","entailment","conditions","considered","relevance","relationship","collapses","classical","computations","providing","regularization","processes","computational","generalized","particular","statistical","algorithms","documentation","modelling","dependent","optimization","implementation","downloaded","operators","investigated","determine","increasing","multivariate","effectiveness","especially","detection","automatic","statistics","stationary","experiment","normalization","anomalies","autoencoder","publishing","management","configuration","diagnosis","containing","similarity","difficult","reconstruction","essential","framework","discriminate","asymptotically","significant","different","theoretically","hypothesis","experiments","incomplete","classification","designing","interpretable","analyzing","discrepancy","divergence","selection","extremely","furthermore","statistically","applications","adversarial","estimator","successfully","dimensional","measuring","important","underlying","nonparametric","establish","collections","construction","constructing","population","allocation","dependency","simulation","documents","published","sophisticated","guarantees","wasserstein","adaptation","efficiency","frameworks","theoretical","advantages","unsupervised","minimizing","probability","generalization","transportation","combining","transport","blockmodel","measurements","consisting","observations","representation","membership","blockmodels","relationships","stochastic","approximate","assumptions","exchangeability","relational","interaction","regulatory","information","complexity","explosion","simplification","proximity","distributional","translation","polysemic","exponential","neighbors","combinatorial","selecting","candidates","determining","disambiguation","comparison","coherence","processing","straightforward","retrieval","introduced","functions","eliminates","elimination","utilities","competitive","challenge","arbitrarily","approximating","integrates","marginalizing","iteratively","remaining","equivalent","demonstrated","properties","possibility","performed","evaluated","connecting","resources","realistic","structures","researchers","simulations","consequences","following","estimators","estimated","resulting","polytopes","parameters","groundings","adjustments","exploiting","contributions","formulation","generalizes","quantitatively","estimation","marginals","characterize","constants","interpretability","complicated","regression","combination","reproducing","described"," ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	blockmodels
# 	exchangeability
# 	marginalizing
# 	semiparametric
# 	bernsteins
# 	integrable
# 	mcallester
# 	criticism
# 	endmember
# 	oftentimes
# 	terabytes
# 	pediatric
# 	inferential
# 	sparsifying
# 	economists
# 	asymptotics
# 	inhomogeneity
# 	wirtinger
# 	rehabilitation
# 	accommodating
# Some words which never appear in Statistics papers:
# 	contradiction
# 	propositional
# 	proposition
# 	polysemic
# 	disambiguation
# 	groundings
# 	messaging
# 	plagiarism
# 	characterised
# 	approximable
# 	calligraphy
# 	deformation
# 	diffeomorphic
# 	utilising
# 	purchased
# 	thelearning
# 	utterances
# 	apparently
# 	unlimited
# 	indicative

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.0673905708413856e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7825
